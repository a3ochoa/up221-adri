# %%
#print("Source: CalEnviroScreen")

#print("The data set I hope to use for my research is contained within the most recent CalEnviroScreen 4.0 dataset. CalEnviroScreen is a digital tool that helps to understand the pollution burden in various communities within California. The specific information that I am interested within this dataset is use of pesticides and pesticide particulate matter in Fresno County and health disparities in the population. I hope to use this to explore community health impacts.")

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
#read and add shapefile to notebook

# %%
#read and add csvfile to notebook

# %%
#read and add csv file to notebook

# %%
CES=gpd.read_file('calenviroscreen40resultsdatadictionary_F_2021.xlsx - CES4.0FINAL_results.csv')

# %%
#what is the data type?
type(CES)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#what does the data look like?

# %%
CES.head()
# Out:
#   Census Tract Total Population California County    ZIP Approximate Location  \
# 0   6019001100             2780           Fresno   93706               Fresno
# 1   6077000700             4680       San Joaquin  95206             Stockton
# 2   6037204920             2751       Los Angeles  90023          Los Angeles
# 3   6019000700             3664           Fresno   93706               Fresno
# 4   6019000200             2689           Fresno   93706               Fresno
#
#       Longitude    Latitude CES 4.0 Score CES 4.0 Percentile  \
# 0  -119.7816961  36.7096952         93.18             100.00
# 1  -121.2878729  37.9431727         86.65              99.99
# 2  -118.1974975  34.0175004         82.39              99.97
# 3  -119.8277069  36.7345353         81.33              99.96
# 4  -119.8055044  36.7354914         80.75              99.95
#
#    CES 4.0 Percentile Range  ... Poverty Poverty Pctl Unemployment  \
# ...

# %%
#give me the lst three of the data set
CES.tail(3)
# Out:
#      Census Tract Total Population California County    ZIP  \
# 7717   6061021309            14332           Placer   95765
# 7718   6041110200             5016            Marin   94901
# 7719   6097153807             3459           Sonoma   95448
#
#                    Approximate Location     Longitude    Latitude  \
# 7717                            Rocklin  -121.2796761  38.8268169
# 7718                         San Rafael  -122.4741961  37.9856076
# 7719  Unincorporated Sonoma County area  -122.7450282  38.5679564
#
#      CES 4.0 Score CES 4.0 Percentile CES 4.0 Percentile Range  ... Poverty  \
# 7717          4.78               2.71     1-5% (lowest scores)  ...     9.2
# 7718          4.78               2.70     1-5% (lowest scores)  ...     4.4
# 7719          4.77               2.69     1-5% (lowest scores)  ...     4.1
#
#      Poverty Pctl Unemployment Unemployment Pctl Housing Burden  \
# 7717         8.38          4.4             36.44            8.5
# ...

# %%
#give me a sample of the dataset
CES.sample(2)
# Out:
#      Census Tract Total Population California County    ZIP  \
# 7146   6097153903             3876           Sonoma   95448
# 6144   6071009717             4216    San Bernardino  92307
#
#      Approximate Location     Longitude    Latitude CES 4.0 Score  \
# 7146           Healdsburg  -122.8571471   38.618985          8.69
# 6144         Apple Valley  -117.2606458  34.5196207         13.83
#
#      CES 4.0 Percentile CES 4.0 Percentile Range  ... Poverty Poverty Pctl  \
# 7146               9.91                    5-10%  ...    10.8        11.95
# 6144              22.54                   20-25%  ...    30.8        55.11
#
#      Unemployment Unemployment Pctl Housing Burden Housing Burden Pctl  \
# 7146          2.6             11.87           10.4               15.50
# 6144          8.2             76.69            8.2                7.39
#
#      Pop. Char. Pop. Char. Score Pop. Char. Pctl geometry
# 7146      22.24             2.31           10.05     None
# ...

# %%
CES.info
# Out:
# <bound method DataFrame.info of      Census Tract Total Population California County    ZIP  \
# 0      6019001100             2780           Fresno   93706
# 1      6077000700             4680       San Joaquin  95206
# 2      6037204920             2751       Los Angeles  90023
# 3      6019000700             3664           Fresno   93706
# 4      6019000200             2689           Fresno   93706
# ...           ...              ...               ...    ...
# 7715   6001408000             2700          Alameda   94619
# 7716   6013345116             2794      Contra Costa  94583
# 7717   6061021309            14332           Placer   95765
# 7718   6041110200             5016            Marin   94901
# 7719   6097153807             3459           Sonoma   95448
#
#                    Approximate Location     Longitude    Latitude  \
# 0                                Fresno  -119.7816961  36.7096952
# 1                              Stockton  -121.2878729  37.9431727
# ...

# %%
#how many rows and columns? 
CES.shape
# Out:
# (7720, 59)

# %%
#what are the columns? 
CES.columns
# Out:
# Index(['Census Tract', 'Total Population', 'California County', 'ZIP',
#        'Approximate Location', 'Longitude', 'Latitude', 'CES 4.0 Score',
#        'CES 4.0 Percentile', 'CES 4.0 Percentile Range', 'Ozone', 'Ozone Pctl',
#        'PM2.5', 'PM2.5 Pctl', 'Diesel PM', 'Diesel PM Pctl', 'Drinking Water',
#        'Drinking Water Pctl', 'Lead', 'Lead Pctl', 'Pesticides',
#        'Pesticides Pctl', 'Tox. Release', 'Tox. Release Pctl', 'Traffic',
#        'Traffic Pctl', 'Cleanup Sites', 'Cleanup Sites Pctl',
#        'Groundwater Threats', 'Groundwater Threats Pctl', 'Haz. Waste',
#        'Haz. Waste Pctl', 'Imp. Water Bodies', 'Imp. Water Bodies Pctl',
#        'Solid Waste', 'Solid Waste Pctl', 'Pollution Burden',
#        'Pollution Burden Score', 'Pollution Burden Pctl', 'Asthma',
#        'Asthma Pctl', 'Low Birth Weight', 'Low Birth Weight Pctl',
#        'Cardiovascular Disease', 'Cardiovascular Disease Pctl', 'Education',
# ...

# %%
CES.info
# Out:
# <bound method DataFrame.info of      Census Tract Total Population California County    ZIP  \
# 0      6019001100             2780           Fresno   93706
# 1      6077000700             4680       San Joaquin  95206
# 2      6037204920             2751       Los Angeles  90023
# 3      6019000700             3664           Fresno   93706
# 4      6019000200             2689           Fresno   93706
# ...           ...              ...               ...    ...
# 7715   6001408000             2700          Alameda   94619
# 7716   6013345116             2794      Contra Costa  94583
# 7717   6061021309            14332           Placer   95765
# 7718   6041110200             5016            Marin   94901
# 7719   6097153807             3459           Sonoma   95448
#
#                    Approximate Location     Longitude    Latitude  \
# 0                                Fresno  -119.7816961  36.7096952
# 1                              Stockton  -121.2878729  37.9431727
# ...

# %%
#give the first five of the dataset
CES.head(5)
# Out:
#   Census Tract Total Population California County    ZIP Approximate Location  \
# 0   6019001100             2780           Fresno   93706               Fresno
# 1   6077000700             4680       San Joaquin  95206             Stockton
# 2   6037204920             2751       Los Angeles  90023          Los Angeles
# 3   6019000700             3664           Fresno   93706               Fresno
# 4   6019000200             2689           Fresno   93706               Fresno
#
#       Longitude    Latitude CES 4.0 Score CES 4.0 Percentile  \
# 0  -119.7816961  36.7096952         93.18             100.00
# 1  -121.2878729  37.9431727         86.65              99.99
# 2  -118.1974975  34.0175004         82.39              99.97
# 3  -119.8277069  36.7345353         81.33              99.96
# 4  -119.8055044  36.7354914         80.75              99.95
#
#    CES 4.0 Percentile Range  ... Poverty Poverty Pctl Unemployment  \
# ...

# %%
#list of desired column names
desired_columns=['California County','Pesticides']

#list of desired rows
desired_rows=['Fresno','Unincorporated Fresno County area']

CES[desired_columns].sample(5)

#plot a simple line graph
CES.plot()
# Out:
# <AxesSubplot: >

# %%
CES.value_counts()
# Out:
# Series([], dtype: int64)

# %%
#sample of desired data
CES[desired_columns].sample(10)
# Out:
#      California County Pesticides
# 660        Los Angeles       0.00
# 6394         San Mateo       0.00
# 6071          Alameda        0.00
# 6249       Santa Clara       0.00
# 6301         San Diego      81.48
# 6034         San Diego       0.00
# 7000           Orange        0.00
# 3186    San Bernardino       0.00
# 1270             Kern        0.00
# 2902       Los Angeles       0.00
