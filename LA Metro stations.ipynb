# %% [markdown]
# # Mapping Metro Stations with Walking Buffer

# %%
#first import geopandas to work with the shapefiles

# %%
import pandas as pd
import geopandas as gpd

# %%
#import the Data 
metro = gpd.read_file('Metro Stations.zip')
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %%
#check to see if data imported

# %%
metro.head(201)
# Out:
#     LINE  LINENUM  LINENUM2  STNSEQ  STNSEQ2    DIR  STOPNUM  \
# 0   Blue      801         0      21        0   None    80101
# 1   Blue      801         0      22        0  North    80102
# 2   Blue      801         0      18        0   None    80105
# 3   Blue      801         0      17        0   None    80106
# 4   Blue      801         0      16        0   None    80107
# ..   ...      ...       ...     ...      ...    ...      ...
# 91  Gold      804         0       5        0   None    80423
# 92  Gold      804         0       4        0   None    80424
# 93  Gold      804         0       3        0   None    80425
# 94  Gold      804         0       2        0   None    80426
# 95  Gold      804         0       1        0   None    80427
#
#                           STATION        LAT        LONG  TPIS_NAME  \
# 0     Downtown Long Beach Station  33.768071 -118.192921   Long Bch
# 1             Pacific Ave Station  33.772258 -118.193700    Pacific
# 2          Anaheim Street Station  33.781830 -118.189384    Anaheim
# 3       Pacific Coast Hwy Station  33.789090 -118.189382        PCH
# 4           Willow Street Station  33.807079 -118.189834     Willow
# ..                            ...        ...         ...        ...
# 91               Monrovia Station  34.133155 -118.003473   Monrovia
# 92  Duarte / City of Hope Station  34.132518 -117.967680     Duarte
# 93              Irwindale Station  34.129048 -117.932506  Irwindale
# 94         Azusa Downtown Station  34.135863 -117.906631      Azusa
# 95   APU / Citrus College Station  34.136814 -117.891636    APU/Cit
#
#          POINT_X       POINT_Y                     geometry
# 0   6.503030e+06  1.738034e+06  POINT (-118.19292 33.76807)
# 1   6.502796e+06  1.739558e+06  POINT (-118.19370 33.77226)
# 2   6.504115e+06  1.743039e+06  POINT (-118.18938 33.78183)
# 3   6.504120e+06  1.745681e+06  POINT (-118.18938 33.78909)
# 4   6.503995e+06  1.752228e+06  POINT (-118.18983 33.80708)
# ..           ...           ...                          ...
# 91  6.560616e+06  1.870840e+06  POINT (-118.00347 34.13316)
# 92  6.571447e+06  1.870610e+06  POINT (-117.96768 34.13252)
# 93  6.582093e+06  1.869352e+06  POINT (-117.93251 34.12905)
# 94  6.589921e+06  1.871838e+06  POINT (-117.90663 34.13586)
# 95  6.594458e+06  1.872189e+06  POINT (-117.89164 34.13681)
#
# [96 rows x 14 columns]

# %%
#data types
metro.dtypes
# Out:
# LINE           object
# LINENUM         int64
# LINENUM2        int64
# STNSEQ          int64
# STNSEQ2         int64
# DIR            object
# STOPNUM         int64
# STATION        object
# LAT           float64
# LONG          float64
# TPIS_NAME      object
# POINT_X       float64
# POINT_Y       float64
# geometry     geometry
# dtype: object

# %%
#map metro stops
metro.plot()
# Out:
# <AxesSubplot: >

# %%
#trim columns
desired_columns = ['LINE','LINENUM','STATION','LAT','LONG','geometry']

# %%
# check to see if columns have been trimmed
metro[desired_columns].sample(1)
# Out:
#    LINE  LINENUM                          STATION        LAT        LONG  \
# 33  Red      802  Universal / Studio City Station  34.140002 -118.362699
#
#                        geometry
# 33  POINT (-118.36270 34.14000)

# %%
metro_trimmed = metro[desired_columns].copy()
metro_trimmed
# Out:
#     LINE  LINENUM                        STATION        LAT        LONG  \
# 0   Blue      801    Downtown Long Beach Station  33.768071 -118.192921
# 1   Blue      801            Pacific Ave Station  33.772258 -118.193700
# 2   Blue      801         Anaheim Street Station  33.781830 -118.189384
# 3   Blue      801      Pacific Coast Hwy Station  33.789090 -118.189382
# 4   Blue      801          Willow Street Station  33.807079 -118.189834
# ..   ...      ...                            ...        ...         ...
# 91  Gold      804               Monrovia Station  34.133155 -118.003473
# 92  Gold      804  Duarte / City of Hope Station  34.132518 -117.967680
# 93  Gold      804              Irwindale Station  34.129048 -117.932506
# 94  Gold      804         Azusa Downtown Station  34.135863 -117.906631
# 95  Gold      804   APU / Citrus College Station  34.136814 -117.891636
#
#                        geometry
# 0   POINT (-118.19292 33.76807)
# 1   POINT (-118.19370 33.77226)
# 2   POINT (-118.18938 33.78183)
# 3   POINT (-118.18938 33.78909)
# 4   POINT (-118.18983 33.80708)
# ..                          ...
# 91  POINT (-118.00347 34.13316)
# 92  POINT (-117.96768 34.13252)
# 93  POINT (-117.93251 34.12905)
# 94  POINT (-117.90663 34.13586)
# 95  POINT (-117.89164 34.13681)
#
# [96 rows x 6 columns]

# %%
#now to overlay city boundaries. We will only be looking at data within the city of LA.

# %%
municipalities=gpd.read_file('City_Boundaries.geojson')
municipalities.head()
# Out:
#    OBJECTID      CITY_NAME     CITY_LABEL  ABBR  OF_AREA_SM CITY_TYPE  \
# 0         3  Redondo Beach  Redondo Beach  RBCH       6.349      City
# 1         4     Long Beach     Long Beach    LB      50.309      City
# 2         5  Redondo Beach  Redondo Beach  RBCH       6.349      City
# 3         6    Los Angeles    Los Angeles    LA     468.852      City
# 4         7     Long Beach     Long Beach    LB      50.309      City
#
#     FEAT_TYPE                COLOR_EGIS                URL       PHONE  \
# 0  Breakwater    Pink - RGB 255,190,232    www.redondo.org  3103721171
# 1       Water  Purple - RGB 185,185,250  www.longbeach.gov  5625706555
# 2  Breakwater    Pink - RGB 255,190,232    www.redondo.org  3103721171
# 3  Breakwater    Gray - RGB 178,178,178     www.lacity.org  2134733231
# 4  Breakwater  Purple - RGB 185,185,250  www.longbeach.gov  5625706555
#
#            last_edited_date   ShapeSTArea  ShapeSTLength  \
# 0 2022-07-20 00:08:28+00:00  2.483437e+05    7484.640344
# 1 2022-07-20 00:08:28+00:00  4.000260e+06   20369.924519
# 2 2022-07-20 00:08:28+00:00  9.452611e+03     701.117043
# 3 2022-07-20 00:08:28+00:00  2.857692e+05   17391.983014
# 4 2022-07-20 00:08:28+00:00  1.097324e+05    5448.776853
#
#                                             geometry
# 0  POLYGON ((-118.39951 33.84377, -118.39952 33.8...
# 1  POLYGON ((-118.21061 33.72181, -118.21064 33.7...
# 2  POLYGON ((-118.39150 33.83193, -118.39160 33.8...
# 3  POLYGON ((-118.26566 33.70405, -118.26574 33.7...
# 4  POLYGON ((-118.11850 33.74278, -118.11855 33.7...

# %%
#First, plot the city map and the metro map
lacity=municipalities.query("CITY_NAME == 'Los Angeles'").copy()

# %%
lacity.plot(figsize=(15,12))
metro.plot(figsize=(15,12))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### LA Metro Stops

# %%
#now, we create a clipping mask by overlaying the data
citymetro = gpd.clip(metro, lacity)
citymetro.plot(figsize=(15,12))
# Out:
# <AxesSubplot: >

# %%
#now we just have the metro stops within the city. Next, we will add a .25 mile buffer zone around the stations. 
#This will help to create walksheds around the stations. 
#NOTE: STILL A WORK IN PROGRESS. NEED TO LEARN HOW TO DO BUFFER IN PYTHON

# %% [markdown]
# ## Buffer Zones
